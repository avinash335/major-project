# %% [markdown]
# <a href="https://colab.research.google.com/github/avinash335/major-project/blob/main/pre_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications.vgg16 import VGG16

model = VGG16(weights='imagenet',include_top=False)
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
import matplotlib.pyplot as plt
from keras.preprocessing import image

x = image.load_img('/content/pneumonia.jpg',target_size=(224,224))
plt.imshow(x)

# %%
from keras.applications.vgg16 import preprocess_input,decode_predictions
import numpy as np

x = image.img_to_array(x)
x = np.expand_dims(x,axis =0)
x = preprocess_input(x)

# %%
y= model.predict(x)
label = decode_predictions(y)
label
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8d9be8c21ab9> in <module>()
#       1 y= model.predict(x)
# ----> 2 label = decode_predictions(y)
#       3 label
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/applications/vgg16.py in decode_predictions(preds, top)
#     234 @keras_export('keras.applications.vgg16.decode_predictions')
#     235 def decode_predictions(preds, top=5):
# --> 236   return imagenet_utils.decode_predictions(preds, top=top)
#     237
#     238
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/applications/imagenet_utils.py in decode_predictions(preds, top)
#     149                      'a batch of predictions '
#     150                      '(i.e. a 2D array of shape (samples, 1000)). '
# --> 151                      'Found array with shape: ' + str(preds.shape))
# ...
